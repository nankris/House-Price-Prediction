# %%
import os
os.chdir("C:\\Users\\Poori\\Desktop\\Delloite\\AirBnB10K")

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
houses_train=pd.read_csv("train10k.csv")
houses_test=pd.read_csv("test2k.csv")

# %%
houses_train.head()
# Out:
#          id  log_price property_type        room_type  \
# 0   5506438   4.605170     Apartment  Entire home/apt
# 1  12343026   5.010635     Apartment  Entire home/apt
# 2   9493786   4.077537         House     Private room
# 3   9961396   5.686975     Apartment  Entire home/apt
# 4   4820071   5.991465     Apartment  Entire home/apt
#
#                                            amenities  accommodates  bathrooms  \
# 0  {"Wireless Internet","Wheelchair accessible",K...             3        1.0
# 1  {TV,"Cable TV",Internet,"Wireless Internet","A...             2        1.0
# 2  {"Wireless Internet",Kitchen,"Free parking on ...             3        1.5
# 3  {"Cable TV",Internet,"Wireless Internet","Air ...             1        1.0
# 4  {TV,Pool,Kitchen,Gym,Elevator,Heating,"Family/...             3        1.0
#
#    bed_type cancellation_policy  cleaning_fee  ...   latitude   longitude  \
# 0  Real Bed            flexible         False  ...  40.859270  -73.929658
# 1  Real Bed            flexible          True  ...  40.738295  -74.006016
# 2  Real Bed            moderate          True  ...  40.662847  -73.946532
# 3  Real Bed            flexible         False  ...  40.796835  -73.970703
# 4  Real Bed              strict          True  ...  37.782340 -122.397179
#
#                                               name       neighbourhood  \
# 0  Spacious 1 Bd. Apt. Inwood near Fort Tryon Park  Washington Heights
# 1                Lovely 1BR West Village Apartment        West Village
# 2              2. Private Room with nice queen bed       East Flatbush
# 3               Upper West Side Large Private Bdrm     Upper West Side
# 4                               GREAT location!!!!                SoMa
#
#   number_of_reviews review_scores_rating  \
# 0                 0                  NaN
# 1                 0                  NaN
# 2                 0                  NaN
# 3                 0                  NaN
# 4                 4                 90.0
#
#                                        thumbnail_url zipcode bedrooms  beds
# 0  https://a0.muscache.com/im/pictures/8d65b600-3...   10040      2.0   1.0
# 1  https://a0.muscache.com/im/pictures/9c1b8f62-1...   10014      1.0   1.0
# 2  https://a0.muscache.com/im/pictures/756d845e-3...   11225      1.0   1.0
# 3  https://a0.muscache.com/im/pictures/106971386/...   10025      1.0   1.0
# 4  https://a0.muscache.com/im/pictures/105087954/...   94107      1.0   1.0
#
# [5 rows x 29 columns]

# %%
houses_test.columns
houses_test[]
# Out:
# Index(['id', 'property_type', 'room_type', 'amenities', 'accommodates',
#        'bathrooms', 'bed_type', 'cancellation_policy', 'cleaning_fee', 'city',
#        'description', 'first_review', 'host_has_profile_pic',
#        'host_identity_verified', 'host_response_rate', 'host_since',
#        'instant_bookable', 'last_review', 'latitude', 'longitude', 'name',
#        'neighbourhood', 'number_of_reviews', 'review_scores_rating',
#        'thumbnail_url', 'zipcode', 'bedrooms', 'beds'],
#       dtype='object')

# %%
houses_train.columns
# Out:
# Index(['id', 'log_price', 'property_type', 'room_type', 'amenities',
#        'accommodates', 'bathrooms', 'bed_type', 'cancellation_policy',
#        'cleaning_fee', 'city', 'description', 'first_review',
#        'host_has_profile_pic', 'host_identity_verified', 'host_response_rate',
#        'host_since', 'instant_bookable', 'last_review', 'latitude',
#        'longitude', 'name', 'neighbourhood', 'number_of_reviews',
#        'review_scores_rating', 'thumbnail_url', 'zipcode', 'bedrooms', 'beds'],
#       dtype='object')

# %%
houses_test.columns
# Out:
# Index(['id', 'property_type', 'room_type', 'amenities', 'accommodates',
#        'bathrooms', 'bed_type', 'cancellation_policy', 'cleaning_fee', 'city',
#        'description', 'first_review', 'host_has_profile_pic',
#        'host_identity_verified', 'host_response_rate', 'host_since',
#        'instant_bookable', 'last_review', 'latitude', 'longitude', 'name',
#        'neighbourhood', 'number_of_reviews', 'review_scores_rating',
#        'thumbnail_url', 'zipcode', 'bedrooms', 'beds'],
#       dtype='object')

# %%
houses_train["property_type"].unique()
# Out:
# array(['Apartment', 'House', 'Timeshare', 'Villa', 'Condominium',
#        'Townhouse', 'Loft', 'Serviced apartment', 'Bungalow',
#        'Boutique hotel', 'Guest suite', 'Other', 'Guesthouse',
#        'Bed & Breakfast', 'Camper/RV', 'Castle', 'Cabin', 'Hostel',
#        'Boat', 'Tipi', 'Dorm', 'Tent', 'Chalet', 'In-law', 'Cave',
#        'Earth House', 'Vacation home', 'Treehouse'], dtype=object)

# %%
houses_train.describe()
# Out:
#                  id     log_price  accommodates    bathrooms      latitude  \
# count  1.000000e+04  10000.000000   10000.00000  9974.000000  10000.000000
# mean   1.121862e+07      4.790830       3.14660     1.240525     38.426223
# std    6.086583e+06      0.719634       2.15573     0.590796      3.078567
# min    3.362000e+03      1.609438       1.00000     0.000000     33.343287
# 25%    6.185343e+06      4.317488       2.00000     1.000000     34.127979
# 50%    1.220670e+07      4.744932       2.00000     1.000000     40.659715
# 75%    1.635534e+07      5.220356       4.00000     1.000000     40.745598
# max    2.120388e+07      7.569412      16.00000     8.000000     42.390437
#
#           longitude  number_of_reviews  review_scores_rating     bedrooms  \
# count  10000.000000       10000.000000           7714.000000  9986.000000
# mean     -92.481286          20.532900             94.106041     1.261065
# std       21.710604          36.447603              7.929820     0.846945
# min     -122.510941           0.000000             20.000000     0.000000
# 25%     -118.343094           1.000000             92.000000     1.000000
# 50%      -77.001433           6.000000             96.000000     1.000000
# 75%      -73.954729          23.000000            100.000000     1.000000
# max      -70.985047         530.000000            100.000000     8.000000
#
#               beds
# count  9977.000000
# mean      1.705823
# std       1.215609
# min       1.000000
# 25%       1.000000
# 50%       1.000000
# 75%       2.000000
# max      16.000000

# %%
houses_train["room_type"].unique()
# Out:
# array(['Entire home/apt', 'Private room', 'Shared room'], dtype=object)

# %%
len(list(houses_train["amenities"].unique()))
# Out:
# 9673

# %%
#houses=pd.concat([houses_train,houses_test],keys=['train','test'])
#houses.head()

# %%
#houses_test.head()
from sklearn.preprocessing import OneHotEncoder 
houses_train['amenities'].head()
# Out:
# 0    {"Wireless Internet","Wheelchair accessible",K...
# 1    {TV,"Cable TV",Internet,"Wireless Internet","A...
# 2    {"Wireless Internet",Kitchen,"Free parking on ...
# 3    {"Cable TV",Internet,"Wireless Internet","Air ...
# 4    {TV,Pool,Kitchen,Gym,Elevator,Heating,"Family/...
# Name: amenities, dtype: object

# %%
houses_train['amenities']=houses_train['amenities'].str.replace("{","")
houses_train['amenities']=houses_train['amenities'].str.replace("}","")
houses_train['amenities']
# Out:
# 0       "Wireless Internet","Wheelchair accessible",Ki...
# 1       TV,"Cable TV",Internet,"Wireless Internet","Ai...
# 2       "Wireless Internet",Kitchen,"Free parking on p...
# 3       "Cable TV",Internet,"Wireless Internet","Air c...
# 4       TV,Pool,Kitchen,Gym,Elevator,Heating,"Family/k...
#                               ...
# 9995    TV,"Cable TV",Internet,"Wireless Internet",Kit...
# 9996    "Wireless Internet","Air conditioning",Kitchen...
# 9997    "Wireless Internet","Air conditioning",Kitchen...
# 9998    "Wireless Internet","Air conditioning",Kitchen...
# 9999    TV,Internet,"Wireless Internet","Air condition...
# Name: amenities, Length: 10000, dtype: object

# %%
count=0
lst=[]
for i in houses_train['amenities']:
    st=i.split(',')
    lst.extend(st)
    lst=set(lst)
    lst=list(lst)
    count+=1
    #if count==3:
    #    break

#print(lst)
#print(i)
j=houses_train['amenities'][0]
#print(j.split(','))
l=j.split(',')
k=list(i.split(','))
#i.split(',').replace("{","").replace("}","")

len(lst)
lst.pop(0)
lst
# Out:
# ['Bathtub',
#  'Breakfast',
#  'Dryer',
#  '"Wireless Internet"',
#  '"Private bathroom"',
#  'Smartlock',
#  '"Babysitter recommendations"',
#  'Hangers',
#  '"BBQ grill"',
#  '"Safety card"',
#  '"Hot tub"',
#  '"Pets allowed"',
#  '"Path to entrance lit at night"',
#  '"Handheld shower head"',
#  '"Buzzer/wireless intercom"',
#  '"Firm mattress"',
#  'Doorman',
#  '"Changing table"',
#  '"Baby bath"',
#  '"Cooking basics"',
#  '"Paid parking off premises"',
#  'Shampoo',
#  '"translation missing: en.hosting_amenity_49"',
#  '"Suitable for events"',
#  '"Hot water kettle"',
#  '"Patio or balcony"',
#  '"Extra pillows and blankets"',
#  '"Window guards"',
#  '"Ethernet connection"',
#  '"Air conditioning"',
#  '"Other pet(s)"',
#  'Essentials',
#  '"Coffee maker"',
#  '"Lock on bedroom door"',
#  '"Wheelchair accessible"',
#  '"translation missing: en.hosting_amenity_50"',
#  '"First aid kit"',
#  '"Wide clearance to shower & toilet"',
#  '"Cleaning before checkout"',
#  '"Step-free access"',
#  'Waterfront',
#  'Crib',
#  'Cat(s)',
#  '"Smart lock"',
#  'Dog(s)',
#  '"Pocket wifi"',
#  '"Ground floor access"',
#  '"Washer / Dryer"',
#  '"Ski in/Ski out"',
#  'Dishwasher',
#  '"Accessible-height toilet"',
#  '"Game console"',
#  '"Outlet covers"',
#  'Refrigerator',
#  '"Pets live on this property"',
#  '"Long term stays allowed"',
#  '"Wide clearance to bed"',
#  '"Well-lit path to entrance"',
#  '"Smoking allowed"',
#  '"Bathtub with shower chair"',
#  '"Cable TV"',
#  '"Host greets you"',
#  '"Fireplace guards"',
#  '"Wide doorway"',
#  'Internet',
#  '"Free parking on premises"',
#  '"Laptop friendly workspace"',
#  '"24-hour check-in"',
#  '"Accessible-height bed"',
#  '"Elevator in building"',
#  '"Luggage dropoff allowed"',
#  'Washer',
#  '"Private entrance"',
#  '"Fixed grab bars for shower & toilet"',
#  '"Smoke detector"',
#  '"Family/kid friendly"',
#  '"Stair gates"',
#  '"Wide hallway clearance"',
#  '"Flat smooth pathway to front door"',
#  '"High chair"',
#  'Lockbox',
#  '"Disabled parking spot"',
#  'Beachfront',
#  'Pool',
#  'Iron',
#  '"Wide entryway"',
#  '"Children’s dinnerware"',
#  '"Firm matress"',
#  '"Indoor fireplace"',
#  '"Pack ’n Play/travel crib"',
#  'Other',
#  '"Doorman Entry"',
#  '"Fire extinguisher"',
#  '"Hair dryer"',
#  '"Hot water"',
#  '"Self Check-In"',
#  'Heating',
#  '"Garden or backyard"',
#  '"EV charger"',
#  '"Children’s books and toys"',
#  '"Free parking on street"',
#  '"Beach essentials"',
#  '"Room-darkening shades"',
#  'Kitchen',
#  '"Dishes and silverware"',
#  ' smooth pathway to front door"',
#  '"Flat',
#  '"Table corner guards"',
#  'Microwave',
#  'Elevator',
#  '"Private living room"',
#  '"Carbon monoxide detector"',
#  'TV',
#  'Gym',
#  '"Air purifier"',
#  '"Baby monitor"',
#  '"Bed linens"',
#  'Keypad',
#  'Oven',
#  '"Single level home"',
#  '"Lake access"',
#  'Stove']

# %%
houses_train_copy=houses_train.copy()
for i in lst:
    houses_train_copy[i]=0
#houses_train_copy['"Changing table"']
st=[]
row=0
for i in houses_train_copy['amenities']:
    st=i.split(',')
    for i in st:
        houses_train_copy.loc[row,i]=1
        #houses_train_copy[i][row]=1
    row+=1
houses_train_copy['"Changing table"']
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 9995    0
# 9996    0
# 9997    0
# 9998    0
# 9999    0
# Name: "Changing table", Length: 10000, dtype: int64

# %%
houses_train_copy=houses_train_copy.iloc[:,0:151]
print(houses_train_copy.iloc[:,150].value_counts())
print(houses_train_copy.iloc[:,150].head())
# Out:
# 0    9445
# 1     555
# Name: Stove, dtype: int64
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: Stove, dtype: int64

# %%
houses_train_copy[houses_train_copy['"Changing table"']==1]
# Out:
#             id  log_price property_type        room_type  \
# 183    3432296   6.212606     Apartment  Entire home/apt
# 355   19823304   5.918894     Apartment  Entire home/apt
# 489   14202480   4.867534     Apartment  Entire home/apt
# 884   13164444   5.293305         House  Entire home/apt
# 961    6613140   4.700480     Apartment  Entire home/apt
# 1768   9505047   4.605170     Apartment  Entire home/apt
# 1988   7842355   6.396930         House  Entire home/apt
# 2188  14278303   4.077537         House     Private room
# 2283  15549517   5.843544     Apartment  Entire home/apt
# 2414   3689473   5.910797         House  Entire home/apt
# 2822  19141765   6.907755         House  Entire home/apt
# 2865   9133627   4.595120     Apartment  Entire home/apt
# 2995   3241287   6.549651     Apartment  Entire home/apt
# 3386  10686929   6.744059     Townhouse  Entire home/apt
# 3882   8474340   5.129899         House  Entire home/apt
# 4167  15220582   5.703782         House  Entire home/apt
# 4169   8281889   6.684612         House  Entire home/apt
# 4212  17452640   4.234107    Guesthouse  Entire home/apt
# 4880   7734698   5.347108         House  Entire home/apt
# 6229   5327921   4.465908     Apartment  Entire home/apt
# 7165  17534186   5.703782     Apartment  Entire home/apt
# 7216  14821940   7.130899          Boat  Entire home/apt
# 7526   9516417   4.499810     Apartment  Entire home/apt
# 7809  11498469   5.940171         House  Entire home/apt
# 8925  18855595   4.418841   Condominium     Private room
# 8988  19175637   5.752573   Condominium  Entire home/apt
# 9027  13479810   5.187386         House  Entire home/apt
# 9038   1025173   5.978886         House  Entire home/apt
# 9124   9777669   5.241747     Townhouse  Entire home/apt
# 9208  13219681   5.416100     Apartment  Entire home/apt
# 9763   1488883   6.214608     Apartment  Entire home/apt
# 9952   6577974   3.761200     Apartment     Private room
#
#                                               amenities  accommodates  \
# 183   TV,Internet,"Wireless Internet",Kitchen,"Buzze...             8
# 355   TV,Internet,"Wireless Internet","Air condition...             6
# 489   "Wireless Internet","Air conditioning",Kitchen...             4
# 884   TV,"Wireless Internet","Air conditioning",Pool...             8
# 961   Internet,"Wireless Internet","Air conditioning...             2
# 1768  TV,"Wireless Internet","Air conditioning",Kitc...             8
# 1988  TV,"Cable TV","Wireless Internet",Kitchen,"Fre...             6
# 2188  Internet,"Wireless Internet","Air conditioning...             2
# 2283  TV,"Cable TV","Wireless Internet","Air conditi...             5
# 2414  TV,Internet,"Wireless Internet","Air condition...            11
# 2822  TV,"Cable TV",Internet,"Wireless Internet","Ai...             8
# 2865  TV,Internet,"Wireless Internet","Air condition...             6
# 2995  TV,"Cable TV",Internet,"Wireless Internet","Ai...             6
# 3386  TV,"Cable TV",Internet,"Wireless Internet","Ai...            10
# 3882  TV,Internet,"Wireless Internet","Air condition...             5
# 4167  TV,"Cable TV",Internet,"Wireless Internet",Kit...             5
# 4169  TV,"Wireless Internet",Kitchen,"Indoor firepla...            12
# 4212  "Wireless Internet","Free parking on premises"...             2
# 4880  TV,"Cable TV",Internet,"Wireless Internet","Ai...             6
# 6229  TV,"Cable TV","Wireless Internet","Air conditi...             4
# 7165  TV,"Wireless Internet","Air conditioning",Kitc...             4
# 7216  TV,"Cable TV",Internet,"Wireless Internet","Ai...             8
# 7526  "Wireless Internet","Air conditioning",Kitchen...             3
# 7809  "Wireless Internet",Kitchen,"Indoor fireplace"...             6
# 8925  TV,"Wireless Internet",Kitchen,Heating,Washer,...             2
# 8988  TV,Internet,"Wireless Internet",Kitchen,"Buzze...             2
# 9027  TV,"Cable TV",Internet,"Wireless Internet","Ai...             7
# 9038  TV,"Cable TV",Internet,"Wireless Internet",Kit...            10
# 9124  "Wireless Internet","Air conditioning",Kitchen...             4
# 9208  TV,Internet,"Wireless Internet","Air condition...             4
# 9763  TV,"Wireless Internet","Air conditioning",Kitc...             3
# 9952  TV,"Wireless Internet","Air conditioning",Kitc...             2
#
#       bathrooms       bed_type cancellation_policy  cleaning_fee  ... TV Gym  \
# 183         3.0       Real Bed              strict          True  ...  1   0
# 355         2.0       Real Bed              strict         False  ...  1   0
# 489         1.0       Real Bed            moderate          True  ...  0   0
# 884         2.5       Real Bed              strict          True  ...  1   0
# 961         1.0       Real Bed            flexible          True  ...  0   0
# 1768        1.0       Real Bed            moderate          True  ...  1   0
# 1988        1.5       Real Bed            moderate          True  ...  1   0
# 2188        2.0       Real Bed              strict          True  ...  0   0
# 2283        2.0       Real Bed            flexible         False  ...  1   0
# 2414        2.0       Real Bed              strict          True  ...  1   0
# 2822        2.5       Real Bed            flexible         False  ...  1   0
# 2865        1.5       Real Bed              strict          True  ...  1   0
# 2995        2.0       Real Bed            flexible          True  ...  1   1
# 3386        2.5       Real Bed              strict          True  ...  1   0
# 3882        2.0       Real Bed            moderate          True  ...  1   0
# 4167        2.0       Real Bed              strict          True  ...  1   0
# 4169        3.5       Real Bed              strict          True  ...  1   0
# 4212        1.0       Real Bed            flexible         False  ...  0   0
# 4880        2.5       Real Bed              strict          True  ...  1   0
# 6229        1.0       Real Bed            flexible          True  ...  1   0
# 7165        2.0       Real Bed              strict          True  ...  1   0
# 7216        3.5       Real Bed              strict          True  ...  1   0
# 7526        1.0       Real Bed              strict          True  ...  0   0
# 7809        2.0       Real Bed              strict          True  ...  0   0
# 8925        1.0  Pull-out Sofa            flexible          True  ...  1   0
# 8988        2.0       Real Bed              strict         False  ...  1   0
# 9027        3.0       Real Bed            moderate          True  ...  1   0
# 9038        2.5       Real Bed              strict          True  ...  1   0
# 9124        1.5       Real Bed              strict          True  ...  0   0
# 9208        2.0       Real Bed              strict          True  ...  1   0
# 9763        2.5       Real Bed            flexible          True  ...  1   0
# 9952        1.0       Real Bed            moderate          True  ...  1   0
#
#      "Air purifier" "Baby monitor" "Bed linens" Keypad Oven  \
# 183               0              1            1      1    1
# 355               0              0            0      0    0
# 489               0              0            0      0    1
# 884               0              0            1      1    1
# 961               0              0            0      0    0
# 1768              0              0            0      1    0
# 1988              0              0            1      0    1
# 2188              0              0            0      0    0
# 2283              0              0            0      0    0
# 2414              0              0            0      0    0
# 2822              0              0            0      0    0
# 2865              0              0            0      0    0
# 2995              0              0            1      0    1
# 3386              0              1            0      0    0
# 3882              0              0            0      0    0
# 4167              0              0            0      0    0
# 4169              0              0            0      0    1
# 4212              0              0            0      0    0
# 4880              0              0            0      0    0
# 6229              0              0            1      1    1
# 7165              0              0            0      0    1
# 7216              0              1            0      0    0
# 7526              0              0            0      0    1
# 7809              0              0            0      0    1
# 8925              0              1            0      0    0
# 8988              0              0            1      0    1
# 9027              0              0            0      0    0
# 9038              0              0            1      0    1
# 9124              0              0            1      0    1
# 9208              0              1            0      0    0
# 9763              0              1            0      0    0
# 9952              0              0            0      0    0
#
#      "Single level home" "Lake access"  Stove
# 183                    0             0      1
# 355                    0             0      0
# 489                    0             0      1
# 884                    0             0      1
# 961                    0             0      0
# 1768                   0             0      0
# 1988                   0             0      1
# 2188                   0             0      0
# 2283                   0             0      0
# 2414                   0             0      0
# 2822                   0             0      0
# 2865                   0             0      0
# 2995                   0             0      1
# 3386                   0             0      0
# 3882                   0             0      0
# 4167                   0             0      0
# 4169                   0             0      1
# 4212                   0             0      0
# 4880                   0             0      0
# 6229                   0             0      1
# 7165                   0             0      1
# 7216                   0             0      0
# 7526                   0             0      1
# 7809                   0             0      1
# 8925                   0             0      0
# 8988                   0             0      1
# 9027                   0             0      0
# 9038                   0             0      1
# 9124                   0             0      1
# 9208                   0             0      0
# 9763                   0             0      0
# 9952                   0             0      0
#
# [32 rows x 151 columns]

# %%
list(houses_train.columns)
# Out:
# ['id',
#  'log_price',
#  'property_type',
#  'room_type',
#  'amenities',
#  'accommodates',
#  'bathrooms',
#  'bed_type',
#  'cancellation_policy',
#  'cleaning_fee',
#  'city',
#  'description',
#  'first_review',
#  'host_has_profile_pic',
#  'host_identity_verified',
#  'host_response_rate',
#  'host_since',
#  'instant_bookable',
#  'last_review',
#  'latitude',
#  'longitude',
#  'name',
#  'neighbourhood',
#  'number_of_reviews',
#  'review_scores_rating',
#  'thumbnail_url',
#  'zipcode',
#  'bedrooms',
#  'beds']
